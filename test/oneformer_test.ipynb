# %%
import torch
import pprint
import tomllib
from PIL import Image
from typing import Dict, List, Tuple

from transformers import OneFormerProcessor, OneFormerForUniversalSegmentation

# %%
# %cd ..
# Out:
# /Users/neil/Code/LogicVision

# %%
# !pwd
# Out:
# /Users/neil/Code/LogicVision

# %%
processor = OneFormerProcessor.from_pretrained(
    "cache_pretrained/models--shi-labs--oneformer_ade20k_swin_large/snapshots/4a5bac8e64f82681a12db2e151a4c2f4ce6092b2"
)

model = OneFormerForUniversalSegmentation.from_pretrained(
    "cache_pretrained/models--shi-labs--oneformer_ade20k_swin_large/snapshots/4a5bac8e64f82681a12db2e151a4c2f4ce6092b2"
)

print(f"Processor: {processor}")
print(f"Model: {model}")
# Out:
# /Users/neil/miniconda3/envs/LTNTorch/lib/python3.12/site-packages/transformers/utils/deprecation.py:165: UserWarning: The following named arguments are not valid for `OneFormerImageProcessor.__init__` and were ignored: '_max_size'
#   return func(*args, **kwargs)
# Processor: OneFormerProcessor:
# - image_processor: OneFormerImageProcessor {
#   "class_info_file": "ade20k_panoptic.json",
#   "do_normalize": true,
#   "do_reduce_labels": false,
#   "do_rescale": true,
#   "do_resize": true,
#   "ignore_index": 255,
#   "image_mean": [
#     0.48500001430511475,
#     0.4560000002384186,
#     0.4059999883174896
#   ],
#   "image_processor_type": "OneFormerImageProcessor",
#   "image_std": [
#     0.2290000021457672,
#     0.2239999920129776,
#     0.22499999403953552
#   ],
#   "metadata": {
#     "0": "wall",
#     "1": "building",
#     "10": "cabinet",
#     "100": "poster, posting, placard, notice, bill, card",
#     "101": "stage",
#     "102": "van",
#     "103": "ship",
# ...
